# %%
a=100

# %%
##declaring and assisning variables
age=32
height=6.1
name="krish"
is_student=True
##printing the variables
print("Age:", age)
print("Height:", height)
print("Name:", name)
# Out:
# Age: 32
# Height: 6.1
# Name: krish

# %%
#invalid variable names
#2age=30
#1name="Krish"  #starts with a number

# %%
##understanding variable types
##python is dynamically types,type of variable is determined atruntime
age=25
height=6.1 #float
name="Krish" #string
is_student=True #boolean
print(type(age))        #<class 'int'>
# Out:
# <class 'int'>

# %%
##type checking and conversion
type(height)
# Out:
# float

# %%
age='25'
print(type(int(age)))
# Out:
# <class 'int'>

# %%
nem="krish"
int(name)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[15], line 2
#       1 nem="krish"
# ----> 2 int(name)
#
# ValueError: invalid literal for int() with base 10: 'Krish'

# %%
height=9.9
type(height)
# Out:
# float

# %%
float(int(height))
# Out:
# 9.0

# %%
##dynamic typing
##python allows changing the type of variable during execution
var=10  #int
print(var, type(var))  
var="Hello"  #string
print(var, type(var))
var=5.5  #float
print(var, type(var))
# Out:
# 10 <class 'int'>
# Hello <class 'str'>
# 5.5 <class 'float'>

# %%
## input
age=int(input("Enter your age: "))
print("Your age is:", age)

# %%
###simple calculator
num1=int(input("Enter first number: "))
num2=int(input("Enter second number: "))
sum=num1+num2
print("The sum is:", sum)
###string concatenation
str1=input("Enter first string: ")
str2=input("Enter second string: ")
full_str=str1+" "+str2
print("Concatenated string:", full_str)
###type conversion example
num_str=input("Enter a number: ")
num=int(num_str)
print("The number plus 10 is:", num+10)
###float conversion example
float_str=input("Enter a float number: ")
float_num=float(float_str)
print("The float number plus 5.5 is:", float_num+5.5)

# %%
age=25
print(type(age))

# type conversion
age_str=str(agr)
print(age_str)
print(type(age_str))
# Out:
# <class 'int'>

# %%
##case sensitive
name="krish"
Name="naik"

# %%
#Naming Conventions
##variables name should be descriptive
##They should start with a letter or underscore(_)
##They can contain letters, numbers, and underscores
##They are case-sensitive (age and Age are different variables)
##They should not be a reserved keyword in Python (like if, else, while, etc.)
##valid variable names
first_name="Krish"
last_name="Naik_
# Out:
#   Cell In[5], line 9
#     last_name="Naik_
#               ^
# SyntaxError: unterminated string literal (detected at line 9)
