# %%
a=15
b=44
add_result=a+b
subtract_result=b-a
multiply_result=a*b
divide_result=b/a
floor_div_result=b//a
modulas_results=b%a
exponent_result=a**2

print(add_result)
print(subtract_result)
print(multiply_result)
print(divide_result)
print(floor_div_result)
print(modulas_results)
print(exponent_result)
# Out:
# 59
# 29
# 660
# 2.933333333333333
# 2
# 14
# 225

# %%
10/6

# %%
45+77
