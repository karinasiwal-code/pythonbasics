# %%
import os

new_directory = 'new_folder'
os.mkdir(new_directory)
print(f"Directory '{new_directory}' created")
# Out:
# Directory 'new_folder' created

# %%
##listing files and directories
items=os.listdir('.')
print(items)
# Out:
# ['copy_example.txt', 'example.bin', 'example.txt', 'fileoperation.ipynb', 'filepath.ipynb', 'new_folder']

# %%
### joining paths
import os

dir_name = 'new_folder'
file_name = 'file.txt'

full_path = os.path.join(os.getcwd(), dir_name, file_name)
print(full_path)
# Out:
# c:\Users\Karina Siwal\Downloads\venv\venv   python\1-pythonbasics\6.file handling\new_folder\file.txt

# %%
import os

path = "new_folder"

if os.path.exists(path):
    print(f"The path '{path}' exists")
else:
    print(f"The path '{path}' does not exist")
# Out:
# The path 'new_folder' exists

# %%
## checkinf if a path is a file or directory
import os
path = 'example.txt'
if os.path.isfile(path):
    print(f" the path{path} is a directory")
else:
    print(f" the path{path} is neither a file nor a directory")
# Out:
#  the pathexample.txt is a directory

# %%
## getting the absolute path
relative_path = 'example.txt'
absolute_path = os.path.abspath(relative_path)
print(absolute_path)
# Out:
# c:\Users\Karina Siwal\Downloads\venv\venv   python\1-pythonbasics\6.file handling\example.txt
